# %% [markdown]
# # NEUB CSE-432 Spring 2025 Lab 5

# %% [markdown]
# ## Task 1
# Frequency analysis of Discrete-Time Periodic Signals (Fourier Series)
#
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
# Generating Signal
f1=50
f2=100
f3=150
Fs=1000
L=256
N=512
x=np.zeros(N)
for i in range(L):
    x[i]=np.sin(np.pi*f1*i/Fs)+np.sin(np.pi*f2*i/Fs)+np.sin(np.pi*f3*i/Fs)
plt.plot(x[0:L])    

#Analysis
Ck=np.zeros(N)
for i in range (N):
    for k in range(N):
        Ck[i]=Ck[i]+x[k]*np.exp(-1j*2*np.pi*i*k/N)
plt.figure()    
Y=np.abs(Ck[0:N//2])
plt.plot(Y)       

# Synthesis
x_r=np.zeros(N)
for i in range(N):
    for k in range(N):
        x_r[i]=x_r[i]+Ck[k]*np.exp(1j*2*np.pi*i*k/N)
plt.figure()
plt.plot(x_r[0:L])
# Out:
# <ipython-input-1-afa02e514c15>:19: ComplexWarning: Casting complex values to real discards the imaginary part
#   Ck[i]=Ck[i]+x[k]*np.exp(-1j*2*np.pi*i*k/N)
# <ipython-input-1-afa02e514c15>:28: ComplexWarning: Casting complex values to real discards the imaginary part
#   x_r[i]=x_r[i]+Ck[k]*np.exp(1j*2*np.pi*i*k/N)

# %% [markdown]
# ## Task 2
# Implementing Zero Order Hold DAC

# %%
# To be done by Students

# %% [markdown]
# ## Task 3
# Cross Correlation of two signals
# ```
# x = [1, 2, 3, 4]
# y = [5, 6, 7, 8]```

# %%
# To be done by students

# %% [markdown]
# ## Task 4
# Autocorretaion of signal ``x = [1, 2, 3, 4]``

# %%
# To be done by students

# %% [markdown]
# ## Home Task
# Tasks 2,3, and 4
# 1. Implementing Zero Order Hold DAC
# 2. Cross Correlation of two signals x = [1, 2, 3, 4] & y = [5, 6, 7, 8]
# 3. Autocorretaion of signal x = [1, 2, 3, 4]

# %% [markdown]
# # Lab exam Details
# ## Mark Distribution
# |Assessment|Mark|
# |------|-----|
# |Attendance|10|
# |Lab Performance|20|
# |Lab Final|40|
# |Project|30|
# |**Total**|**100**|
#
# ## Project Submission guideline
# Project must be submitted as part of the final assessment of the course CSE-432 (Digital Signal Processing Lab). All students must adhere to the following guidelines.
# 1. Project can be submitted as an individual project or a group project. In case of group project, the number of members shall not exceed 2.
# 2. For group projects, the works of each member must be distinguishable and each members will be graded according to their work. If any persons work is not sufficiently distinguishable, they will get 0.
# 3. The projects must be a hardware project and must implement any concepts introduced or discussed  in the course. Any irrelevant projects will not be graded. To avoid any confusion regarding type of project, students are advised to approve the project proposal by 15th April 2025. All project proposals must be submitted as hard copy.
# 4. Date of submission of the project will be the day of lab final exam. *NO extension of deadline will be allowed*
# 5. The project submitted in CSE-432 must not overlap with the project submitted in CSE-322. The projects for CSE-322 are supposed to be more hardware oriented and project of CSE-432 should encompass mainly signal processing. Some example of DSP projects include
#     a. Sound/Speech processing
#     b. Image Processing
#     c. Trend identification in data, etc.
